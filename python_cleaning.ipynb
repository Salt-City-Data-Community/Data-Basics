# %% [markdown]
# # Python Data Cleaning: NYC Airbnb Data from 2019
# Source: [New York City Airbnb Open Data](https://www.kaggle.com/dgomonov/new-york-city-airbnb-open-data)
#
# *Please note the source data was modified to create situations for this tutorial.*

# %% [markdown]
# **Overview**
# - [Set up and check data](#Set-up-and-check-data)
# - [Dropping duplicate value rows](#Dropping-duplicate-value-rows)
# - [Changing data types](#Changing-data-types)
# - [Renaming columns](#Renaming-columns)
# - [Dropping columns](#Dropping-columns)
# - [Filling null values in categorical columns](#Filling-null-values-in-categorical-columns)
# - [Filling null values in numerical columns](#Filling-null-values-in-numerical-columns)
# - [Dropping rows with null values](#Dropping-rows-with-null-values)

# %% [markdown]
# ### Set up and check data ###

# %%
# Load pandas and numpy library and stats from the scipy library
import pandas as pd
import numpy as np
from scipy import stats

# %%
# Load CSV of data as a pandas dataframe
raw_data = pd.read_csv('airbnb_nyc_2019.csv')

# %%
raw_data.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room  149.0               1                  9  10/19/2018
# 1  Entire home/apt  225.0               1                 45   5/21/2019
# 2     Private room  150.0               3                  0         NaN
# 3  Entire home/apt   89.0               1                270    7/5/2019
# 4  Entire home/apt   80.0              10                  9  11/19/2018
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %%
print(raw_data.index) # Python indexing starts at 0, unlike R, where indexing starts at 1.
# Out:
# RangeIndex(start=0, stop=48900, step=1)

# %%
raw_data.describe() # Summary statistics for each numeric column
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.890000e+04  4.890000e+04  48900.000000  48900.000000  48888.000000
# mean   1.901753e+07  6.761978e+07     40.728952    -73.952166    152.720074
# std    1.098340e+07  7.861036e+07      0.054535      0.046165    240.166390
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471971e+06  7.820478e+06     40.690098    -73.983072     69.000000
# 50%    1.967743e+07  3.079257e+07     40.723075    -73.955680    106.000000
# 75%    2.915244e+07  1.074344e+08     40.763120    -73.936270    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48900.000000       48900.000000       38846.000000
# mean         7.030102          23.273804           1.373266
# std         20.509799          44.548793           1.680489
# min          1.000000           0.000000           0.010000
# 25%          1.000000           1.000000           0.190000
# 50%          3.000000           5.000000           0.720000
# 75%          5.000000          24.000000           2.020000
# max       1250.000000         629.000000          58.500000
#
#        calculated_host_listings_count  availability_365
# count                    48900.000000      48900.000000
# mean                         7.143374        112.780593
# std                         32.950889        131.620979
# min                          1.000000          0.000000
# 25%                          1.000000          0.000000
# 50%                          1.000000         45.000000
# 75%                          2.000000        227.000000
# max                        327.000000        365.000000

# %%
raw_data.info() # Given index #, column name, counts, and data types for entire dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48900 entries, 0 to 48899
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48900 non-null  int64
#  1   name                            48884 non-null  object
#  2   host_id                         48900 non-null  int64
#  3   host_name                       48879 non-null  object
#  4   neighbourhood_group             48900 non-null  object
#  5   neighbourhood                   48900 non-null  object
#  6   latitude                        48900 non-null  float64
#  7   longitude                       48900 non-null  float64
#  8   room_type                       48900 non-null  object
#  9   price                           48888 non-null  float64
#  10  minimum_nights                  48900 non-null  int64
#  11  number_of_reviews               48900 non-null  int64
#  12  last_review                     38846 non-null  object
#  13  reviews_per_month               38846 non-null  float64
#  14  calculated_host_listings_count  48900 non-null  int64
#  15  availability_365                48900 non-null  int64
# dtypes: float64(4), int64(6), object(6)
# memory usage: 6.0+ MB

# %%
data = raw_data.copy() # Create a copy of the original dataframe to work with

# %% [markdown]
# ### Dropping duplicate value rows ###
# Drop any rows that have a duplicate ID, assuming this should be unique to each listing record.

# %%
data = data.drop_duplicates(subset=['id'])

# %% [markdown]
# ### Changing data types ###
# Change the last_review column to datetime objects.

# %%
data['last_review'] =  pd.to_datetime(data['last_review'], format='%m/%d/%Y')

# %%
data['last_review'].head()
# Out:
# 0   2018-10-19
# 1   2019-05-21
# 2          NaT
# 3   2019-07-05
# 4   2018-11-19
# Name: last_review, dtype: datetime64[ns]

# %% [markdown]
# ### Renaming columns ###
# Change the neighbourhood columns to reflect typical spelling of the word in American English by dropping the 'u'.

# %%
data = data.rename(columns = {'neighbourhood_group' : 'neighborhood_group', 'neighbourhood' : 'neighborhood'})

# %%
data.iloc[:, 4:6].head()
# Out:
#   neighborhood_group  neighborhood
# 0           Brooklyn    Kensington
# 1          Manhattan       Midtown
# 2          Manhattan        Harlem
# 3           Brooklyn  Clinton Hill
# 4          Manhattan   East Harlem

# %% [markdown]
# ### Dropping columns ###
# Create a new column and then remove it.

# %%
data['test_col'] = 5

# %%
data['test_col'].head()
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# 4    5
# Name: test_col, dtype: int64

# %%
data.drop('test_col', axis=1, inplace=True)

# %%
data.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighborhood_group  neighborhood  latitude  longitude  \
# 0         John           Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer          Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth          Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne           Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura          Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room  149.0               1                  9  2018-10-19
# 1  Entire home/apt  225.0               1                 45  2019-05-21
# 2     Private room  150.0               3                  0         NaT
# 3  Entire home/apt   89.0               1                270  2019-07-05
# 4  Entire home/apt   80.0              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %% [markdown]
# ### Filling null values in categorical columns ###
# Fill blanks in the 'name' and 'host_name' columns to signify the data was not provided.

# %%
data[data.isnull().any(axis=1)]
# Out:
#              id                                               name   host_id  \
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 20         7750                  Huge 2 BR Upper East  Cental Park     17985
# 27         8700  Magnifique Suite au N de Manhattan - vue Cloitres     26394
# 37        11452                        Clean and Quiet in Brooklyn      7355
# 39        11943                          Country space in the city     45445
# ...         ...                                                ...       ...
# 48895  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48896  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48897  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48898  36485609               43rd St. Time Square-cozy single bed  30985759
# 48899  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#              host_name neighborhood_group        neighborhood  latitude  \
# 2            Elisabeth          Manhattan              Harlem  40.80902
# 20                Sing          Manhattan         East Harlem  40.79685
# 27     Claude & Sophie          Manhattan              Inwood  40.86754
# 37                  Vt           Brooklyn  Bedford-Stuyvesant  40.68876
# 39             Harriet           Brooklyn            Flatbush  40.63702
# ...                ...                ...                 ...       ...
# 48895          Sabrina           Brooklyn  Bedford-Stuyvesant  40.67853
# 48896          Marisol           Brooklyn            Bushwick  40.70184
# 48897    Ilgar & Aysel          Manhattan              Harlem  40.81475
# 48898              Taz          Manhattan      Hell's Kitchen  40.75751
# 48899       Christophe          Manhattan      Hell's Kitchen  40.76404
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 2      -73.94190     Private room  150.0               3                  0
# 20     -73.94872  Entire home/apt  190.0               7                  0
# 27     -73.92639     Private room   80.0               4                  0
# 37     -73.94312     Private room   35.0              60                  0
# 39     -73.96327     Private room  150.0               1                  0
# ...          ...              ...    ...             ...                ...
# 48895  -73.94995     Private room   70.0               2                  0
# 48896  -73.93317     Private room   40.0               4                  0
# 48897  -73.94867  Entire home/apt  115.0              10                  0
# 48898  -73.99112      Shared room   55.0               1                  0
# 48899  -73.98933     Private room   90.0               7                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 2             NaT                NaN                               1
# 20            NaT                NaN                               2
# 27            NaT                NaN                               1
# 37            NaT                NaN                               1
# 39            NaT                NaN                               1
# ...           ...                ...                             ...
# 48895         NaT                NaN                               2
# 48896         NaT                NaN                               2
# 48897         NaT                NaN                               1
# 48898         NaT                NaN                               6
# 48899         NaT                NaN                               1
#
#        availability_365
# 2                   365
# 20                  249
# 27                    0
# 37                  365
# 39                  365
# ...                 ...
# 48895                 9
# 48896                36
# 48897                27
# 48898                 2
# 48899                23
#
# [10083 rows x 16 columns]

# %%
data.sort_values(by = 'host_name')
# Out:
#              id                                               name    host_id  \
# 38879  30425770                                  Queens Corner Lot  128580688
# 11138   8622301                    Astoria Full Basement Apartment   45354224
# 10316   7899658                                  MANHATTAN LIVING!   40605120
# 5331    3848324                       West Village apt - 2 Bedroom   11495251
# 35173  27903031                Prewar Gem in Middle of Everything!    7580102
# ...         ...                                                ...        ...
# 28044  21901156  Best Deal! Lovely place in Manhattan! Time Squ...  159156636
# 28276  21990808                 ***SLEEPING IN THE GOLDEN PLACE***  159156636
# 30572  23660605    Private Bedroom w/ Balcony view of Central Park  177146433
# 32195  25180572                     Beautiful Cozy Studio Apt. UWS  119609345
# 38995  30468335            LARGE Prospect Lefferts Gardens Bedroom  228750026
#
#                       host_name neighborhood_group     neighborhood  latitude  \
# 38879                    #NAME?             Queens   Queens Village  40.70524
# 11138                      'Cil             Queens          Astoria  40.76914
# 10316           (Ari) HENRY LEE          Manhattan      East Harlem  40.78938
# 5331   (Email hidden by Airbnb)          Manhattan     West Village  40.73123
# 35173  (Email hidden by Airbnb)          Manhattan          Midtown  40.76399
# ...                         ...                ...              ...       ...
# 28044                       NaN          Manhattan   Hell's Kitchen  40.75656
# 28276                       NaN          Manhattan   Hell's Kitchen  40.75835
# 30572                       NaN          Manhattan      East Harlem  40.79766
# 32195                       NaN          Manhattan  Upper West Side  40.77701
# 38995                       NaN           Brooklyn         Flatbush  40.65152
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 38879  -73.73349  Entire home/apt  150.0               1                 51
# 11138  -73.92118     Private room  120.0               2                240
# 10316  -73.94679  Entire home/apt  140.0               7                  3
# 5331   -74.00428  Entire home/apt  200.0               5                  1
# 35173  -73.98077     Private room  139.0               3                  3
# ...          ...              ...    ...             ...                ...
# 28044  -73.99063     Private room  120.0               1                109
# 28276  -73.99065     Private room  120.0               1                 88
# 30572  -73.94824     Private room  139.0               1                  6
# 32195  -73.97667  Entire home/apt  180.0               4                  0
# 38995  -73.95271     Private room   55.0               7                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 38879  2019-07-07               7.43                               1
# 11138  2019-07-01               5.22                               1
# 10316  2017-12-08               0.06                               1
# 5331   2014-08-30               0.02                               1
# 35173  2018-11-17               0.31                               2
# ...           ...                ...                             ...
# 28044  2019-01-01               5.97                               3
# 28276  2018-12-14               4.93                               3
# 30572  2018-08-12               0.46                               1
# 32195         NaT                NaN                               1
# 38995         NaT                NaN                               1
#
#        availability_365
# 38879               248
# 11138               298
# 10316                56
# 5331                  0
# 35173                 0
# ...                 ...
# 28044                 0
# 28276                 0
# 30572                 0
# 32195                 0
# 38995                69
#
# [48895 rows x 16 columns]

# %%
data['host_name'].nunique() # Get count of unique host names. Because there are many, we will focus on replcaing NaNs
# Out:
# 11452

# %%
data['name'] = data['name'].fillna('Not Provided')

# %%
data['host_name'] = data['host_name'].fillna('Not Provided')

# %%
# Other examples seen above, replacing specific strings '(Email hidden by Airbnb)' and '#NAME?'
data = data.replace(to_replace = ('(Email hidden by Airbnb)', '#NAME?'), value = 'Not Provided')

# %%
data.sort_values(by = 'host_name')
# Out:
#              id                                               name    host_id  \
# 11138   8622301                    Astoria Full Basement Apartment   45354224
# 10316   7899658                                  MANHATTAN LIVING!   40605120
# 19545  15628789  Newly Renovate 2 Bedroom Apartment in Central ...  100757200
# 39436  30735480                              Neve recording studio  229693987
# 33966  26895166                                       2018Serenity  202318295
# ...         ...                                                ...        ...
# 41885  32554746                    Clean, Safe, east village room!  112439306
# 47266  35662019                        Cheap price near Timesquare   79269209
# 33879  26834353       Cozy Brooklyn Room - Next to Pratt Institute  133425456
# 29172  22392030  one bedroom apt for long term stay up to 2 months  151728547
# 33139  26139678                   Private cozy room in perfect UWS   18497228
#
#              host_name neighborhood_group         neighborhood  latitude  \
# 11138             'Cil             Queens              Astoria  40.76914
# 10316  (Ari) HENRY LEE          Manhattan          East Harlem  40.78938
# 19545      (Mary) Haiy           Brooklyn            Bay Ridge  40.63461
# 39436              123          Manhattan      Lower East Side  40.71456
# 33966     2018Serenity          Manhattan          East Harlem  40.79424
# ...                ...                ...                  ...       ...
# 41885               빈나          Manhattan      Stuyvesant Town  40.73180
# 47266               소정          Manhattan       Hell's Kitchen  40.75625
# 33879               소정           Brooklyn   Bedford-Stuyvesant  40.69056
# 29172                진          Manhattan      Upper West Side  40.77506
# 33139               현선          Manhattan  Morningside Heights  40.80485
#
#        longitude        room_type   price  minimum_nights  number_of_reviews  \
# 11138  -73.92118     Private room   120.0               2                240
# 10316  -73.94679  Entire home/apt   140.0               7                  3
# 19545  -74.02451  Entire home/apt   126.0               1                188
# 39436  -73.98717  Entire home/apt   600.0               1                  0
# 33966  -73.94290     Private room    50.0               5                  4
# ...          ...              ...     ...             ...                ...
# 41885  -73.97999     Private room   125.0               4                  1
# 47266  -73.99357     Private room    63.0              31                  0
# 33879  -73.95980     Private room    40.0               5                  1
# 29172  -73.98162  Entire home/apt    70.0              15                  0
# 33139  -73.96534     Private room  1200.0              60                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 11138  2019-07-01               5.22                               1
# 10316  2017-12-08               0.06                               1
# 19545  2019-06-24               5.81                               1
# 39436         NaT                NaN                               1
# 33966  2019-06-22               0.39                               1
# ...           ...                ...                             ...
# 41885  2019-03-06               0.24                               1
# 47266         NaT                NaN                               1
# 33879  2018-08-18               0.09                               1
# 29172         NaT                NaN                               1
# 33139         NaT                NaN                               1
#
#        availability_365
# 11138               298
# 10316                56
# 19545               295
# 39436               365
# 33966                32
# ...                 ...
# 41885                 0
# 47266               250
# 33879                 0
# 29172                 0
# 33139               365
#
# [48895 rows x 16 columns]

# %% [markdown]
# ### Filling null values in numerical columns ###
# Use mean, median, and mode to get possible values to use instead of NaN numeric values.

# %%
null_price_ind = data[data['price'].isnull()].index.tolist()
impute_price = data.copy()
missing_prices = impute_price.index.isin(null_price_ind)
impute_price = impute_price[~ missing_prices]

# %%
mean = int(round(np.mean(impute_price['price'])))
median = np.median(impute_price['price'])
mode = stats.mode(impute_price['price'])

print("\tmean: {}".format(mean))
print("\tmedian: {}".format(median))
print("\tmode: {}".format(mode[0]))
# Out:
# 	mean: 153
# 	median: 106.0
# 	mode: [100.]

# %%
# Using the median to fill in null prices
data['price'] = data['price'].fillna(median)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48895 entries, 0 to 48899
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48895 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48895 non-null  object
#  4   neighborhood_group              48895 non-null  object
#  5   neighborhood                    48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  float64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
#  12  last_review                     38843 non-null  datetime64[ns]
#  13  reviews_per_month               38843 non-null  float64
#  14  calculated_host_listings_count  48895 non-null  int64
#  15  availability_365                48895 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(6), object(5)
# memory usage: 6.3+ MB

# %% [markdown]
# ### Dropping rows with null values ###
# Drop rows of a dataframe if they have a null value in a specific column.

# %%
drop_null_data = raw_data.copy()
drop_null_data = drop_null_data.dropna(subset=['reviews_per_month'])

# %%
drop_null_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38846 entries, 0 to 48857
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              38846 non-null  int64
#  1   name                            38840 non-null  object
#  2   host_id                         38846 non-null  int64
#  3   host_name                       38830 non-null  object
#  4   neighbourhood_group             38846 non-null  object
#  5   neighbourhood                   38846 non-null  object
#  6   latitude                        38846 non-null  float64
#  7   longitude                       38846 non-null  float64
#  8   room_type                       38846 non-null  object
#  9   price                           38837 non-null  float64
#  10  minimum_nights                  38846 non-null  int64
#  11  number_of_reviews               38846 non-null  int64
#  12  last_review                     38846 non-null  object
#  13  reviews_per_month               38846 non-null  float64
#  14  calculated_host_listings_count  38846 non-null  int64
#  15  availability_365                38846 non-null  int64
# dtypes: float64(4), int64(6), object(6)
# memory usage: 5.0+ MB
